# %%
# intentando usar notebooks

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing

# %%
# Cargando datos
credits = pd.read_csv("./train.csv")
print(credits.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
#Histograma del atributo clase
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot(x='Credit_Score',data=credits)
plt.title("Credit Score")
plt.show()

# %%
#Histograma de atributos predictores

credits.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(18,18)
plt.show()

# %%
#boxplot de las variables numericas
credits = credits.drop('ID',axis=1)
box_data = credits #variable representing the data array
print(box_data.head())

box_target = credits.Credit_Score #variable representing the labels array
sns.boxplot(data = box_data,width=0.5,fliersize=5)
#sns.set(rc={'figure.figsize':(2,15)})
plt.show()
# Out:
#    Customer_ID  Month           Name   Age          SSN Occupation  \
# 0         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# ...
